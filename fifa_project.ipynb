# %% [markdown]
# Loading Data

# %%
import my_functions as mybib

import pandas as pd 
import matplotlib.pyplot as plt
import statistics as stats
import numpy as np
import seaborn as sns 

# https://github.com/lilitrdavidyan 
# %load_ext autoreload
# %autoreload 2

# %%
raw_train_df = pd.read_csv('fifa21_train.csv')
# display(raw_train_df.describe().T)

raw_validate_df = pd.read_csv('fifa21_validate.csv')
# display(raw_validate_df.describe().T)

# %%
# mybib.showUnique(raw_df)

# %% [markdown]
# Remove Columns we don't need

# %%
# clean training dataset
clean_train_df = mybib.cleaning_process_for_fifa_dataset(raw_train_df)
display(clean_train_df)

# clean validate dataset
clean_validate_df = mybib.cleaning_process_for_fifa_dataset(raw_validate_df)
display(clean_validate_df)
# Out:
#         bp  growth  value  attacking  crossing  finishing  heading_accuracy  \
# 0       CM       1  0.525        258        54         47                43
# 1       ST       0  8.500        365        66         79                76
# 2      CAM       0  9.000        336        73         76                34
# 3      CDM      13  0.275        242        44         42                58
# 4      CDM       8  0.725        249        49         37                61
# ...    ...     ...    ...        ...       ...        ...               ...
# 11695   ST       0  0.550        290        36         72                65
# 11696   LB       5  0.625        224        62         24                51
# 11697   GK       4  1.600         84        12         14                13
# 11698   RM       8  1.100        286        64         66                51
# 11700  CAM       9  0.700        289        43         64                65
#
#        short_passing  volleys  skill  ...  base_stats  ir  pac  sho  pas  dri  \
# 0                 70     44.0    286  ...         357   1   69   51   63   63
# 1                 68     76.0    375  ...         412   2   83   75   68   82
# 2                 78     75.0    424  ...         404   2   80   77   78   86
# 3                 62     36.0    259  ...         329   1   57   44   54   57
# 4                 68     34.0    280  ...         360   1   66   44   60   64
# ...              ...      ...    ...  ...         ...  ..  ...  ...  ...  ...
# 11695             57     60.0    283  ...         337   1   66   68   47   66
# 11696             59     28.0    248  ...         347   1   75   28   56   59
# 11697             29     16.0     96  ...         387   1   72   67   66   72
# 11698             64     41.0    291  ...         337   1   76   60   60   72
# 11700             64     53.0    267  ...         336   1   79   62   56   67
#
#        def  phy  hits  ova
# 0       51   60   3.0   64
# 1       33   71  44.0   77
# 2       27   56  73.0   80
# 3       57   60   7.0   59
# 4       60   66   4.0   65
# ...    ...  ...   ...  ...
# 11695   33   57   4.0   65
# 11696   60   69   3.0   65
# 11697   40   70   3.0   70
# 11698   26   43   6.0   67
# 11700   24   48   8.0   64
#
# [11422 rows x 55 columns]
#        bp  growth  value  attacking  crossing  finishing  heading_accuracy  \
# 0      CB       7  0.975        230        47         21                62
# 1     CAM       5  1.200        298        62         60                44
# 2      GK      17  0.120         48         7          5                11
# 3     CDM      23  0.160        215        38         31                55
# 4     CDM       5  2.300        295        57         59                45
# ...   ...     ...    ...        ...       ...        ...               ...
# 1994   LB      11  0.325        197        59         23                42
# 1995   GK       9  0.190         77        13          9                14
# 1996   RM       0  8.000        332        76         72                34
# 1997  CDM       0  0.140        268        58         44                61
# 1998  CAM      16  0.425        276        49         54                51
#
#       short_passing  volleys  skill  ...  base_stats  ir  pac  sho  pas  dri  \
# 0                60     40.0    228  ...         334   1   64   30   50   50
# 1                62     70.0    330  ...         358   1   74   67   62   74
# 2                21      4.0     52  ...         295   1   56   52   53   55
# 3                59     32.0    224  ...         303   1   58   34   47   52
# 4                78     56.0    327  ...         407   1   67   62   68   70
# ...             ...      ...    ...  ...         ...  ..  ...  ...  ...  ...
# 1994             51     22.0    207  ...         315   1   76   28   46   55
# 1995             34      7.0     70  ...         318   1   60   55   57   62
# 1996             79     71.0    373  ...         388   2   65   69   78   77
# 1997             62     43.0    261  ...         346   1   53   47   58   58
# 1998             70     52.0    300  ...         339   1   64   54   62   62
#
#       def  phy  hits  ova
# 0      66   74  34.0   67
# 1      24   57  12.0   68
# 2      26   53   3.0   54
# 3      53   59   6.0   55
# 4      69   71  45.0   70
# ...   ...  ...   ...  ...
# 1994   53   57   4.0   60
# 1995   30   54   3.0   59
# 1996   39   60  15.0   76
# 1997   61   69   4.0   63
# 1998   50   47   5.0   60
#
# [1949 rows x 55 columns]

# %%
# split train dataset into X and y and fit the encoder 
y = clean_train_df['ova']
X = clean_train_df.drop(['ova'], axis=1)

# minMaxScaler
from sklearn.preprocessing import MinMaxScaler
MinMaxtransformer = MinMaxScaler().fit(X.select_dtypes(include = np.number))

# OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop='first')
encoder.fit(X.select_dtypes(include = object))

# split train dataset into X and y and fit the encoder 
y_validate = clean_validate_df['ova']
X_validate = clean_validate_df.drop(['ova'], axis=1)

# %%
# normalize and encode X 
X = mybib.use_minMaxTransformer_and_oneHotEncoder(X, MinMaxtransformer, encoder)
X_validate = mybib.use_minMaxTransformer_and_oneHotEncoder(X_validate, MinMaxtransformer, encoder)

# %%
# make a train test split
X_train, X_test, y_train, y_test = mybib.split_the_data_into_train_test_datasets(X, y, 0.2)
# Out:
# X_train (9137, 67)
# y_train (9137,)
# X_test (2285, 67)
# y_test (2285,)

# %%
# train model
from sklearn.linear_model import LinearRegression as LinReg

linreg=LinReg()    # model
linreg.fit(X_train, y_train)   # model train
# Out:
# LinearRegression()

# %%
# validate datasets and print results for r2, MSE, RMSE, MAE
print('Train dataset')
mybib.predict_data_and_validate_model(X_train, y_train, linreg)

print('Test dataset')
mybib.predict_data_and_validate_model(X_test, y_test, linreg)

print('Validate dataset')
mybib.predict_data_and_validate_model(X_validate, y_validate, linreg)
# Out:
# Train dataset
# The r2 score is: 0.92.
# The MSE is: 3.753.
# The RMSE is: 1.937.
# The MAE is: 1.503.
#
#
# Test dataset
# The r2 score is: 0.92.
# The MSE is: 3.738.
# The RMSE is: 1.933.
# The MAE is: 1.497.
#
#
# Validate dataset
# The r2 score is: 0.92.
# The MSE is: 3.621.
# The RMSE is: 1.903.
# The MAE is: 1.484.
